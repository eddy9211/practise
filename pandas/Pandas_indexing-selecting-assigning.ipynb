# %%
import pandas as pd
pd.set_option("display.max_rows", 5)

# %%
rv = pd.read_csv('winemag-data-130k-v2.csv',index_col=0)

# %%
rv.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
rv.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
rv['country']
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
print(rv.country[0])
print(rv['country'][0])
# Out:
# Italy
# Italy

# %% [markdown]
# Both loc and iloc are row-first, column-second.

# %%
rv.iloc[,0]
# Out:
#   File "<ipython-input-15-73465e8b3e41>", line 1
#     rv.iloc[,0]
#             ^
# SyntaxError: invalid syntax

# %%
rv.iloc[:,0]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
rv.loc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
rv.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
rv.iloc[[1,2,4],0]
# Out:
# 1    Portugal
# 2          US
# 4          US
# Name: country, dtype: object

# %%
rv.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
rv.loc[0,'country']
# Out:
# 'Italy'

# %%
rv.iloc[0,'country']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-d53de64fb758> in <module>()
# ----> 1 rv.iloc[0,'country']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1735     def _getitem_tuple(self, tup):
#    1736
# -> 1737         self._has_valid_tuple(tup)
#    1738         try:
#    1739             return self._getitem_lowerdim(tup)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
# ...

# %%
rv.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#           taster_name taster_twitter_handle  points
# 0       Kerin O’Keefe          @kerinokeefe      87
# 1          Roger Voss            @vossroger      87
# ...               ...                   ...     ...
# 129969     Roger Voss            @vossroger      90
# 129970     Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %% [markdown]
# **df.iloc[0:1000] will return 1000 entries, while df.loc[0:1000] return 1001 of them! **

# %%
rv.set_index('country')
# Out:
#                                                 description  \
# country
# Italy     Aromas include tropical fruit, broom, brimston...
# Portugal  This is ripe and fruity, a wine that is smooth...
# ...                                                     ...
# France    A dry style of Pinot Gris, this is crisp with ...
# France    Big, rich and off-dry, this is powered by inte...
#
#                             designation  points  price           province  \
# country
# Italy                      Vulkà Bianco      87    NaN  Sicily & Sardinia
# Portugal                       Avidagos      87   15.0              Douro
# ...                                 ...     ...    ...                ...
# France                              NaN      90   32.0             Alsace
# France    Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#          region_1 region_2    taster_name taster_twitter_handle  \
# country
# ...

# %%
rv.country == 'Italy'
# Out:
# 0          True
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
rv.loc[rv.country=='Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
rv.iloc[rv.country=='Italy']
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-32-a6eaaf6641de> in <module>()
# ----> 1 rv.iloc[rv.country=='Italy']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1812
#    1813         if is_bool_indexer(key):
# -> 1814             self._has_valid_type(key, axis)
#    1815             return self._getbool_axis(key, axis=axis)
#    1816
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
# ...

# %%
rv.loc[(rv.country=='Italy') & (rv.points==90)]
# Out:
#        country                                        description  \
# 140      Italy  A big, fat, luscious wine with plenty of toast...
# 141      Italy  This is one of the more complex wines from the...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 140                   Costa Bruna      90   26.0           Piedmont
# 141                Vigna dei Pola      90   45.0           Piedmont
# ...                           ...     ...    ...                ...
# 129961                        NaN      90   30.0  Sicily & Sardinia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia
#
#               region_1 region_2    taster_name taster_twitter_handle  \
# 140     Barbera d'Alba      NaN            NaN                   NaN
# ...

# %%
rv.loc[rv.country.isin(['Italy','France'])]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
rv.loc[rv.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %%
for i in range(5,0,-1):
    print (i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
rv['critic'] = 'everyone'

# %%
rv['critic']
# Out:
# 0         everyone
# 1         everyone
#             ...
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %%
rv['country']=='1'
# Out:
# 0         False
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
rv['reverse_index'] = range(len(rv),0,-1)

# %%
rv.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
rv['reverse_index']
# Out:
# 0         129971
# 1         129970
#            ...
# 129969         2
# 129970         1
# Name: reverse_index, Length: 129971, dtype: int32

# %% [markdown]
# **Exercise 4**: Select the first 10 values from the `description` column in `reviews`. Hint: format your output as a `pandas` `Series`.

# %%
rv.loc[0:9,'description']
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
#                            ...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, Length: 10, dtype: object

# %%
rv.iloc[0:10, 1]
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
#                            ...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, Length: 10, dtype: object

# %%
rv.loc[0:99,['country','variety']]
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# ..       ...                       ...
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %%
rv.loc[rv.country=='Italy']

# %% [markdown]
# **Exercise 14**: Who produces more above-averagely good wines, France or Italy? Select the `country` column, but only  when said `country` is one of those two options, _and_ the `points` column is greater than or equal to 90.

# %%
rv.loc[(rv.country.isin(['Italy','France'])) & (rv.points >=90)]
# Out:
#        country                                        description  \
# 119     France  Medium-gold in color. Complex and inviting nos...
# 120      Italy  Slightly backward, particularly given the vint...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                        designation  points  price  province  \
# 119     Schoenenbourg Grand Cru Vendanges Tardives      92   80.0    Alsace
# 120                            Bricco Rocche Prapó      92   70.0  Piedmont
# ...                                            ...     ...    ...       ...
# 129969                                         NaN      90   32.0    Alsace
# 129970               Lieu-dit Harth Cuvée Caroline      90   21.0    Alsace
#
#        region_1 region_2 taster_name taster_twitter_handle  \
# ...

# %%
1 ==2 & 2==2
# Out:
# False

# %%
1 ==2 or 2==2
# Out:
# True
